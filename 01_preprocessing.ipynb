# %%
import pandas as pd
import numpy as np
import os

# Load dataset from data/raw
file_path = "data/raw/german_credit.csv"
df = pd.read_csv(file_path)

print("Data loaded successfully!")
print("Shape:", df.shape)
df.head()
# Out:
# Data loaded successfully!
# Shape: (1000, 21)
#                 status  duration                            credit_history  \
# 0         ... < 100 DM         6   critical account/other credits existing
# 1    0 <= ... < 200 DM        48  existing credits paid back duly till now
# 2  no checking account        12   critical account/other credits existing
# 3         ... < 100 DM        42  existing credits paid back duly till now
# 4         ... < 100 DM        24           delay in paying off in the past
#
#                purpose  amount                     savings  \
# 0  domestic appliances    1169  unknown/no savings account
# 1  domestic appliances    5951                ... < 100 DM
# 2           retraining    2096                ... < 100 DM
# 3     radio/television    7882                ... < 100 DM
# 4            car (new)    4870                ... < 100 DM
#
#   employment_duration  installment_rate                  personal_status_sex  \
# ...

# %%
# Check null/missing values
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# status                     0
# duration                   0
# credit_history             0
# purpose                    0
# amount                     0
# savings                    0
# employment_duration        0
# installment_rate           0
# personal_status_sex        0
# other_debtors              0
# present_residence          0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# number_credits             0
# job                        0
# people_liable              0
# telephone                  0
# foreign_worker             0
# credit_risk                0
# dtype: int64

# %%
# Example: Fill numeric columns with median, categorical with mode
for col in df.columns:
    if df[col].dtype in ["int64", "float64"]:
        df[col] = df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

print("Missing values handled (no warnings).")
# Out:
# Missing values handled (no warnings).

# %%
# Save cleaned dataset to interim folder
os.makedirs("data/interim", exist_ok=True)
df.to_csv("data/interim/german_credit.csv", index=False)

print("Clean dataset saved to data/interim/german_credit.csv")
# Out:
# Clean dataset saved to data/interim/german_credit.csv
